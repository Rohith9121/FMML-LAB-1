# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohith9121/FMML-LAB-1/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 14:18:56--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   106MB/s    in 0.7s
#
# 2024-03-31 14:18:57 (106 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22749  1705.09353v2  We present a new model, Predictive State Recur...  stat
# 20885  1704.07069v1  Agent modelling involves considering how other...    cs
# 16213  1610.09333v1  We introduce word vectors for the construction...    cs
# 2338    1203.3783v1  Deep Boltzmann machines are in principle power...  stat
# 15157  1502.04938v2  Word reordering is one of the most difficult a...    cs
# ...             ...                                                ...   ...
# 1190    1412.7062v4  Deep Convolutional Neural Networks (DCNNs) hav...    cs
# 7413   1712.06260v1  Accurate diagnosis of psychiatric disorders pl...  stat
# 21767   1303.2892v1  We consider the problem of adaptive stratified...  stat
# 27818  1704.06326v2  During the recent years, correlation filters h...    cs
# 34283  1506.04828v2  An objective critical distance (OCD) has been ...    cs
#
#                                                    title  year  \
# 22749         Predictive State Recurrent Neural Networks  2017
# 20885     Evaluating and Modelling Hanabi-Playing Agents  2017
# 16213        Word Embeddings for the Construction Domain  2016
# 2338   Learning Feature Hierarchies with Centered Dee...  2012
# 15157  A Survey of Word Reordering in Statistical Mac...  2015
# ...                                                  ...   ...
# 1190   Semantic Image Segmentation with Deep Convolut...  2014
# 7413   Deep Neural Generative Model of Functional MRI...  2017
# 21767  Toward Optimal Stratification for Stratified M...  2013
# 27818     Good Features to Correlate for Visual Tracking  2017
# 34283  Significance of the levels of spectral valleys...  2015
#
#                                                 keywords
# 22749  [predictive, recurrent, filtering, prediction,...
# 20885  [modelling, considering, influence, modelling,...
# 16213  [introduce, construction, leveraging, accessib...
# 2338   [boltzmann, principle, extracting, hierarchica...
# 15157  [reordering, difficult, statistical, translati...
# ...                                                  ...
# 1190   [convolutional, performance, classification, d...
# 7413   [diagnosis, psychiatric, disorders, improving,...
# 21767  [stratified, integration, evaluations, partiti...
# 27818  [correlation, spectacular, significantly, perf...
# 34283  [objective, determined, subjective, experiment...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22749    [predictive, recurrent, filtering, prediction,...
# 20885    [modelling, considering, influence, modelling,...
# 16213    [introduce, construction, leveraging, accessib...
# 2338     [boltzmann, principle, extracting, hierarchica...
# 15157    [reordering, difficult, statistical, translati...
#                                ...
# 6267     [framework, consistent, classification, decomp...
# 3463     [transformative, applications, particularly, r...
# 11112    [formulation, factorization, formulation, clus...
# 220      [systematically, strategies, dynamically, arti...
# 6081     [interested, estimating, individual, aggregate...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8723 words.
# Out of those 4564 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="26652eab-a009-4ff3-a167-3e557baf02e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26652eab-a009-4ff3-a167-3e557baf02e7")) {                    Plotly.newPlot(                        "26652eab-a009-4ff3-a167-3e557baf02e7",                        [{"x":["outperform","naturally","prediction","factorized","connections","combining","approaches","functions","dynamical","filtering","interesting","successful","suggesting","statistically","alternative","algorithm","representations","advantages","information","observations","recurrent","predictive","effectively","consistent","regression","initialization","multiplicative","decomposition","architectures","influence","significant","construct","literature","implement","improvement","comparison","evaluating","predictor","consideration","modelling","resulting","capabilities","predictors","highlight","considering","collaborative","construction","competitive","performance","available","leveraging","compression","framework","meaningful","classification","embedding","introduce","benchmarking","accessible","parameter","embeddings","principle","suggestion","unfortunately","increasingly","extracting","boltzmann","activation","modification","hierarchies","unsuccessful","generative","conditioned","demonstrate","structure","initially","hierarchical","hierarchy","hypothesis","phenomena","qualitative","statistical","measuring","reordering","published","community","including","anticipate","comprehensive","understand","efficiency","describes","decreased","important","frameworks","empirical","translation","computational","phenomenon","linguistic","different","characteristics","difficult","collection","challenge","systematic","knowledge","overviews","interpretable","constrained","automatically","constraints","parametric","probabilistic","sequences","alignments","classical","simultaneously","unsupervised","alignment","dimensional","algorithmic","providing","suggested","distortion","generators","nonlinear","curvature","conditions","estimates","demonstrated","generalize","variables","stochastic","characterized","interpolants","distributions","variational","geometric","algorithms","formalism","connected","riemannian","significantly","convolutional","distances","architecture","distorted","probability","autoencoders","nonlinearity","generator","clustering","complexity","assumptions","additional","techniques","dependence","rademacher","independent","diagnosis","searching","nonetheless","developed","particular","gathering","sophisticated","desirable","reasoning","inference","economical","exploited","reporting","conversational","diagnostic","discussed","utilizing","terminological","formulated","definition","investigates","introduced","manufacturing","presented","maximizing","automation","objectives","interactions","environment","containing","typically","production","potential","completed","intersection","generates","approximate","development","specifically","formulation"],"y":[87,46,249,2,54,112,412,218,20,63,74,77,21,21,95,806,242,80,684,91,132,60,115,90,136,25,10,79,126,67,250,82,133,77,145,134,60,19,25,59,132,55,13,21,73,32,71,119,904,279,45,43,574,53,493,106,362,11,15,118,61,46,2,29,52,56,11,33,23,13,1,99,15,569,307,15,102,33,61,27,64,161,33,4,36,70,238,9,65,62,159,102,7,366,26,170,112,294,23,66,744,80,162,85,160,46,367,1,37,78,182,140,35,164,111,20,107,116,137,46,184,36,81,30,26,8,67,11,137,81,83,46,118,121,27,1,120,47,69,594,24,78,9,293,360,39,219,10,158,20,5,37,137,232,66,102,347,32,4,127,55,45,6,204,267,6,31,28,144,222,1,30,11,18,20,61,43,3,42,49,31,122,7,202,34,11,28,59,114,62,102,22,167,8,14,58,112,135,167,84],"type":"bar"},{"x":["outperform","naturally","prediction","factorized","connections"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4564,), (4564, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Targetable</span> <span style=''>Named</span> <span style=''>Entity</span> <span style='background-color:rgba(0, 255, 0, 0.598233995584989);'>Recognition</span> <span style=''>in</span> <span style=''>Social</span> <span style=''>Media</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.826086956521739);'>recognizing</span> <span style=''>what</span> <span style=''>we</span> <span style=''>call</span> <span style=''>targetable</span> <span style=''>named</span> <span style=''>entities</span> <span style=''>that</span> <span style=''>is</span> <span style=''>named</span> <span style=''>entities</span> <span style=''>in</span> <span style=''>a</span> <span style=''>targeted</span> <span style=''>set</span> <span style=''>(eg</span> <span style=''>movies</span> <span style=''>books</span> <span style=''>TV</span> <span style=''>shows)</span> <span style=''>Unlike</span> <span style=''>many</span> <span style=''>other</span> <span style=''>NER</span> <span style=''>systems</span> <span style=''>that</span> <span style=''>need</span> <span style=''>to</span> <span style=''>retrain</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3060344827586208);'>statistical</span> <span style=''>models</span> <span style=''>as</span> <span style=''>new</span> <span style=''>entities</span> <span style=''>arrive</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>does</span> <span style=''>not</span> <span style=''>require</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>retraining</span> <span style=''>which</span> <span style=''>makes</span> <span style=''>it</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.5999999999999999);'>adaptable</span> <span style=''>for</span> <span style=''>types</span> <span style=''>of</span> <span style=''>entities</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>frequently</span> <span style=''>updated</span> <span style=''>For</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.380281690140845);'>preliminary</span> <span style=''>study</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>one</span> <span style=''>entity</span> <span style=''>type</span> <span style=''>movie</span> <span style=''>title</span> <span style=''>using</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collected</span> <span style=''>from</span> <span style=''>Twitter</span> <span style=''>Our</span> <span style=''>system</span> <span style=''>is</span> <span style=''>tested</span> <span style=''>on</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.46062052505966583);'>evaluation</span> <span style=''>sets</span> <span style=''>one</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>only</span> <span style=''>entities</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style=''>to</span> <span style=''>movies</span> <span style=''>in</span> <span style=''>our</span> <span style=''>training</span> <span style=''>set</span> <span style=''>and</span> <span style=''>the</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>excluding</span> <span style=''>any</span> <span style=''>of</span> <span style=''>those</span> <span style=''>entities</span> <span style=''>Our</span> <span style=''>final</span> <span style=''>model</span> <span style=''>shows</span> <span style=''>F1</span> <span style=''>scores</span> <span style=''>of</span> <span style=''>7619</span> <span style=''>and</span> <span style=''>7870</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Multivariate</span> <span style=''>Hawkes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <span style=''>for</span> <span style=''>Large</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>fitting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>Hawkes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>for</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>problems</span> <span style=''>both</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>events</span> <span style=''>in</span> <span style=''>the</span> <span style=''>observed</span> <span style=''>history</span> <span style=''>n</span> <span style=''>and</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>event</span> <span style=''>types</span> <span style=''>d</span> <span style=''>(ie</span> <span style=''>dimensions)</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>Low</span> <span style=''>Rank</span> <span style=''>Hawkes</span> <span style=''>Process</span> <span style=''>(LRHP)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>a</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>matrix</span> <span style=''>that</span> <span style=''>allows</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>learning</span> <span style=''>of</span> <span style=''>the</span> <span style=''>d2</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>triggering</span> <span style=''>kernels</span> <span style=''>using</span> <span style=''>at</span> <span style=''>most</span> <span style=''>O(ndr2)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>operations</span> <span style=''>where</span> <span style=''>r</span> <span style=''>is</span> <span style=''>the</span> <span style=''>rank</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>(r</span> <span style=''>ll</span> <span style=''>dn)</span> <span style=''>This</span> <span style=''>comes</span> <span style=''>as</span> <span style=''>a</span> <span style=''>major</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improvement</span> <span style=''>to</span> <span style=''>the</span> <span style=''>existing</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>are</span> <span style=''>in</span> <span style=''>O(nd2)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>the</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>allows</span> <span style=''>LRHP</span> <span style=''>to</span> <span style=''>learn</span> <span style='background-color:rgba(255, 0, 0, 0.3) ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Bayesian</span> <span style=''>Network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classifier</span> <span style=''>that</span> <span style=''>Combines</span> <span style=''>a</span> <span style=''>Finite</span> <span style=''>Mixture</span> <span style=''>Model</span> <span style=''>and</span> <span style=''>a</span> <span style=''>Naive</span> <span style=''>Bayes</span> <span style=''>Model</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>Bayesian</span> <span style=''>network</span> <span style=''>model</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>that</span> <span style=''>combines</span> <span style=''>the</span> <span style=''>naive</span> <span style=''>Bayes</span> <span style=''>(NB)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>and</span> <span style=''>the</span> <span style=''>finite</span> <span style=''>mixture</span> <span style=''>(FM)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>aims</span> <span style=''>at</span> <span style=''>relaxing</span> <span style=''>the</span> <span style=''>strong</span> <span style='background-color:rgba(255, 0, 0, 0.35922330097087385);'>assumptions</span> <span style=''>on</span> <span style=''>which</span> <span style=''>the</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>models</span> <span style=''>are</span> <span style=''>based</span> <span style=''>in</span> <span style=''>an</span> <span style=''>attempt</span> <span style=''>to</span> <span style=''>improve</span> <span style=''>on</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>both</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>accuracy</span> <span style=''>and</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>calibration</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>The</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>is</span> <span style=''>obtained</span> <span style=''>by</span> <span style=''>superimposing</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>mixture</span> <span style=''>model</span> <span style=''>on</span> <span style=''>the</span> <span style=''>set</span> <span style=''>of</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.4085213032581453);'>variables</span> <span style=''>of</span> <span style=''>a</span> <span style=''>naive</span> <span style=''>Bayes</span> <span style=''>model</span> <span style=''>We</span> <span style=''>present</span> <span style='background-color:rgba(0, 255, 0, 0.34186471663619744);'>experimental</span> <span style=''>results</span> <span style=''>that</span> <span style=''>compare</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.38461538461538464);'>predictive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>on</span> <span style=''>real</span> <span style=''>datasets</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Convergence</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>kernel</span> <span style=''>LMS</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>with</span> <span style=''>pre</span> <span style=''>tuned</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <br/><br/><span style=''>The</span> <span style=''>kernel</span> <span style=''>least</span> <span style=''>mean</span> <span style=''>square</span> <span style=''>(KLMS)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appealing</span> <span style=''>tool</span> <span style=''>for</span> <span style=''>online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identification</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>systems</span> <span style=''>due</span> <span style=''>to</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simplicity</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>to</span> <span style=''>choosing</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reproducing</span> <span style=''>kernel</span> <span style=''>and</span> <span style=''>setting</span> <span style=''>filter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>designing</span> <span style=''>a</span> <span style=''>KLMS</span> <span style=''>adaptive</span> <span style=''>filter</span> <span style=''>requires</span> <span style=''>to</span> <span style=''>select</span> <span style=''>a</span> <span style=''>so</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>get</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>order</span> <span style=''>model</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>has</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>impact</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>and</span> <span style=''>requires</span> <span style=''>careful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consideration</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Theoretical</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>KLMS</span> <span style=''>as</span> <span style=''>a</span> <span style=''>function</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>setting</span> <span style=''>has</span> <span style=''>rarely</span> <span style=''>if</span> <span style=''>ever</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addressed</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>In</span> <span style=''>an</span> <span style=''>analysis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>previously</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>published</span> <span style=''>by</span> <span style=''>the</span> <span style=''>authors</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>elements</span> <span style=''>were</span> <span style=''>assumed</spa ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	reasoning (0.05102763997165131)
# 	knowledge (0.130049610205528)
# 	representation (0.13997165131112685)
# 	evaluation (0.10843373493975904)
# 	segmentation (0.07158043940467754)
# 	information (0.24238128986534374)
# 	different (0.26364280652019845)
# 	detection (0.12969525159461376)
# 	recognition (0.12827781715095676)
# 	convolutional (0.12756909992912827)
#
# Some Statistics words are:
# 	stochastic (0.13346814964610718)
# 	statistical (0.1531850353892821)
# 	variables (0.14206268958543983)
# 	theoretical (0.15672396359959556)
# 	estimation (0.1744186046511628)
# 	inference (0.1916076845298281)
# 	algorithm (0.3993933265925177)
# 	distribution (0.1911021233569262)
# 	dimensional (0.18604651162790697)
# 	regression (0.18402426693629928)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2c751e8f-6e06-4b1b-a205-9927bda71770" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c751e8f-6e06-4b1b-a205-9927bda71770")) {                    Plotly.newPlot(                        "2c751e8f-6e06-4b1b-a205-9927bda71770",                        [{"x":["outperform","naturally","prediction","factorized","connections","combining","approaches","functions","dynamical","filtering","interesting","successful","suggesting","statistically","alternative","algorithm","representations","advantages","information","observations","recurrent","predictive","effectively","consistent","regression","initialization","multiplicative","decomposition","architectures","influence","significant","construct","literature","implement","improvement","comparison","evaluating","predictor","consideration","modelling","resulting","capabilities","predictors","highlight","considering","collaborative","construction","competitive","performance","available","leveraging","compression","framework","meaningful","classification","embedding","introduce","benchmarking","accessible","parameter","embeddings","principle","suggestion","unfortunately","increasingly","extracting","boltzmann","activation","modification","hierarchies","unsuccessful","generative","conditioned","demonstrate","structure","initially","hierarchical","hierarchy","hypothesis","phenomena","qualitative","statistical","measuring","reordering","published","community","including","anticipate","comprehensive","understand","efficiency","describes","decreased","important","frameworks","empirical","translation","computational","phenomenon","linguistic","different","characteristics","difficult","collection","challenge","systematic","knowledge","overviews","interpretable","constrained","automatically","constraints","parametric","probabilistic","sequences","alignments","classical","simultaneously","unsupervised","alignment","dimensional","algorithmic","providing","suggested","distortion","generators","nonlinear","curvature","conditions","estimates","demonstrated","generalize","variables","stochastic","characterized","interpolants","distributions","variational","geometric","algorithms","formalism","connected","riemannian","significantly","convolutional","distances","architecture","distorted","probability","autoencoders","nonlinearity","generator","clustering","complexity","assumptions","additional","techniques","dependence","rademacher","independent","diagnosis","searching","nonetheless","developed","particular","gathering","sophisticated","desirable","reasoning","inference","economical","exploited","reporting","conversational","diagnostic","discussed","utilizing","terminological","formulated","definition","investigates","introduced","manufacturing","presented","maximizing","automation","objectives","interactions","environment","containing","typically","production","potential","completed","intersection","generates","approximate","development","specifically","formulation","transition","restricted","incorporate","historical","behaviors","autonomous","sometimes","interactive","complicated","scenarios","automated","selection","reinforcement","complication","objective","strategies","representation","challenging","furthermore","representative","partition","cardinality","partitioning","partitions","intriguing","accelerate","particularly","observing","application","arbitrary","previously","additionally","underlying","generally","competition","amazoncom","expressiveness","stability","forecaster","covariates","electricity","nonparametric","seasonality","forecasting","accommodates","orderings","evaluated","preference","illustrated","differentiate","acceptable","proposition","certainty","defenders","complementary","p ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	seasonality
# 	neuroscientists
# 	debiasing
# 	subgaussian
# 	embarrassingly
# 	manufacturability
# 	distinguishability
# 	encrypted
# 	compensated
# 	blockwise
# 	kronecker
# 	impression
# 	timeseries
# 	fluctuation
# 	corporation
# 	unprocessed
# 	linearities
# 	uhlenbeck
# 	microarrays
# 	diffusing
# Some words which never appear in Statistics papers:
# 	reordering
# 	conversational
# 	terminological
# 	proposition
# 	certainty
# 	argumentation
# 	acceptability
# 	unlimited
# 	annotating
# 	perennial
# 	inevitably
# 	buildings
# 	openstreetmap
# 	erroneously
# 	metastases
# 	gigapixel
# 	aesthetics
# 	photographic
# 	downsampling
# 	upsampling

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0502684236212788e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7608333333333334
